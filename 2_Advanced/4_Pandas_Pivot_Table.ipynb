# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.pivot_table(index='job_title_short', aggfunc='size')   # size counts all rows in a group, count counts non-NA values in a group
# Out:
# job_title_short
# Business Analyst              49063
# Cloud Engineer                12331
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Machine Learning Engineer     14080
# Senior Data Analyst           29216
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Software Engineer             44929
# dtype: int64

# %%
# another way

df.groupby('job_title_short').size()
# Out:
# job_title_short
# Business Analyst              49063
# Cloud Engineer                12331
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Machine Learning Engineer     14080
# Senior Data Analyst           29216
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Software Engineer             44929
# dtype: int64

# %%
df.pivot_table(values = 'salary_year_avg', index='job_title_short', aggfunc='median')
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %%
df.groupby('job_title_short')['salary_year_avg'].median()  # another way using group by
# Out:
# job_title_short
# Business Analyst              85000.0
# Cloud Engineer                90000.0
# Data Analyst                  90000.0
# Data Engineer                125000.0
# Data Scientist               127500.0
# Machine Learning Engineer    106415.0
# Senior Data Analyst          111175.0
# Senior Data Engineer         147500.0
# Senior Data Scientist        155500.0
# Software Engineer             99150.0
# Name: salary_year_avg, dtype: float64

# %%
df.pivot_table(index = 'job_country', columns = 'job_title_short', values='salary_year_avg', aggfunc='median')

# index = rows
# columns = columns
# values = what we want to aggregate
# aggfunc = aggregate function (sum/max/median etc)
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# Albania                       NaN             NaN      49950.00
# Algeria                       NaN             NaN      44100.00
# Argentina                 71100.0        197500.0      92771.75
# Armenia                       NaN             NaN     100500.00
# Australia                 70000.0        110000.0     109500.00
# ...                           ...             ...           ...
# Uruguay                       NaN             NaN     100500.00
# Uzbekistan                    NaN             NaN           NaN
# Vietnam                   79200.0             NaN      75550.00
# Zambia                        NaN             NaN           NaN
# Zimbabwe                      NaN             NaN      63000.00
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# Albania                    NaN        69981.25                        NaN
# ...

# %%
# my try pk
df_1 = df[df['job_country'].isin(['United States','India','United Kingdom','France','Germany','Spain']) & df['job_title_short'].isin(['Data Engineer','Data Analyst','Data Scientist'])]
# Out:
#        job_title_short                                          job_title  \
# 2        Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3        Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5        Data Engineer                                  GCP Data Engineer
# 9       Data Scientist                                  Data Scientist II
# 11       Data Engineer                                      Data Engineer
# ...                ...                                                ...
# 785724   Data Engineer                 Junior Consultant Data Engineering
# 785725  Data Scientist                                 Analytics Engineer
# 785729   Data Engineer               Data Engineer Marketing Intelligence
# 785732   Data Engineer                              Data Engineer (f/m/d)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                               job_location                     job_via  \
# ...

# %%
top_countries = df['job_country'].value_counts().head(6).index
top_countries
# Out:
# Index(['United States', 'India', 'United Kingdom', 'France', 'Germany',
#        'Spain'],
#       dtype='object', name='job_country')

# %%
df_job_country_salary = df.pivot_table(
    values = 'salary_year_avg', 
    index = 'job_country', 
    columns = 'job_title_short', 
    aggfunc='median'
)

# %%
df_job_country_salary = df_job_country_salary.loc[top_countries]

job_titles = ['Data Engineer','Data Analyst','Data Scientist']

df_job_country_salary = df_job_country_salary[job_titles]

df_job_country_salary
# Out:
# job_title_short  Data Engineer  Data Analyst  Data Scientist
# job_country
# United States         125000.0       90000.0        130000.0
# India                 147500.0      100500.0        114008.0
# United Kingdom        110000.0       87750.0        105300.0
# France                 98301.5       69175.0         88128.0
# Germany               147500.0      103750.0        131560.0
# Spain                 133000.0       91977.0         88128.0

# %%
df_job_country_salary.plot(kind='bar')
plt.xlabel('')
plt.ylabel('Median Salary ($USD)')
plt.title('Median Salary by Country and Job Title')
plt.xticks(rotation = 45, ha='right') 
plt.show()
