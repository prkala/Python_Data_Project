# %%
# Example of the explode method

import pandas as pd

data = {
    'job_title_short': ['Data Analyst', 'Data Scientist', 'Data Engineer'],
    'job_skills': [['excel', 'sql', 'python'], ['python', 'r'], ['aws', 'python', 'airflow']]
}

df_skill_lists = pd.DataFrame(data)

df_skill_lists
# Out:
#   job_title_short              job_skills
# 0    Data Analyst    [excel, sql, python]
# 1  Data Scientist             [python, r]
# 2   Data Engineer  [aws, python, airflow]

# %%
df_skill_lists.value_counts('job_skills')  # we will get a type error since lists are unhashable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df_skill_lists.value_counts('job_skills')
#
# File d:\anaconda3\envs\python_course\Lib\site-packages\pandas\core\frame.py:7509, in DataFrame.value_counts(self, subset, normalize, sort, ascending, dropna)
#    7506     subset = self.columns.tolist()
#    7508 name = "proportion" if normalize else "count"
# -> 7509 counts = self.groupby(subset, dropna=dropna, observed=False)._grouper.size()
#    7510 counts.name = name
#    7512 if sort:
#
# File d:\anaconda3\envs\python_course\Lib\site-packages\pandas\core\groupby\ops.py:705, in BaseGrouper.size(self)
#     700 @final
#     701 def size(self) -> Series:
#     702     """
#     703     Compute group sizes.
#     704     """
# --> 705     ids, _, ngroups = self.group_info
#     706     out: np.ndarray | list
#     707     if ngroups:
#
# ...

# %%
df_skill_lists.explode('job_skills')
# Out:
#   job_title_short job_skills
# 0    Data Analyst      excel
# 0    Data Analyst        sql
# 0    Data Analyst     python
# 1  Data Scientist     python
# 1  Data Scientist          r
# 2   Data Engineer        aws
# 2   Data Engineer     python
# 2   Data Engineer    airflow

# %%
df_skill_lists.explode('job_skills').value_counts('job_skills')
# Out:
# job_skills
# python     3
# airflow    1
# aws        1
# excel      1
# r          1
# sql        1
# Name: count, dtype: int64

# %%
df_skill_lists.explode('job_skills').value_counts('job_skills').plot(kind='bar')
# Out:
# <Axes: xlabel='job_skills'>

# %% [markdown]
# ## Pandas Explode

# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df[['job_title_short','job_skills']].head()
# Out:
#         job_title_short                                         job_skills
# 0  Senior Data Engineer                                               None
# 1          Data Analyst         [r, python, sql, nosql, power bi, tableau]
# 2         Data Engineer  [python, sql, c#, azure, airflow, dax, docker,...
# 3         Data Engineer  [python, c++, java, matlab, aws, tensorflow, k...
# 4         Data Engineer  [bash, python, oracle, aws, ansible, puppet, j...

# %%
help(df.explode)
# Out:
# Help on method explode in module pandas.core.frame:
#
# explode(column: 'IndexLabel', ignore_index: 'bool' = False) -> 'DataFrame' method of pandas.core.frame.DataFrame instance
#     Transform each element of a list-like to a row, replicating index values.
#
#     Parameters
#     ----------
#     column : IndexLabel
#         Column(s) to explode.
#         For multiple columns, specify a non-empty list with each element
#         be str or tuple, and all specified columns their list-like data
#         on same row of the frame must have matching length.
#
#         .. versionadded:: 1.3.0
#             Multi-column explode
#
#     ignore_index : bool, default False
#         If True, the resulting index will be labeled 0, 1, …, n - 1.
#
#     Returns
#     -------
#     DataFrame
#         Exploded lists to rows of the subset columns;
#         index will be duplicated for these rows.
#
#     Raises
#     ------
#     ValueError :
# ...

# %%
df.explode('job_skills')
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# ...                      ...
# 785739         Data Engineer
# 785739         Data Engineer
# 785739         Data Engineer
# 785740     Software Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# ...                                                   ...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# ...

# %%
df_exploded = df.explode('job_skills').copy()

# %%
df_exploded
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# ...                      ...
# 785739         Data Engineer
# 785739         Data Engineer
# 785739         Data Engineer
# 785740     Software Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# ...                                                   ...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# ...

# %%
df_exploded['job_skills'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='job_skills'>

# %%
## same thing: df_exploded.groupby(['job_skills', 'job_title_short']).size()

skills_count = df_exploded.groupby(['job_title_short', 'job_skills']).size()

type(skills_count)
# Out:
# pandas.core.series.Series

# %%
skills_count
# Out:
# job_title_short    job_skills
# Business Analyst   airflow        318
#                    airtable        17
#                    alteryx       1078
#                    angular         87
#                    ansible        120
#                                  ...
# Software Engineer  wrike            4
#                    wsl             13
#                    xamarin         35
#                    yarn           145
#                    zoom           229
# Length: 2256, dtype: int64

# %%
df_skills_count = skills_count.reset_index(name = 'skill_count')   # converting series into a dataframe and naming the count column as 'skill_count'

df_skills_count = df_skills_count.sort_values(by='skill_count', ascending=False)

df_skills_count
# Out:
#        job_title_short  job_skills  skill_count
# 1066    Data Scientist      python       113711
# 865      Data Engineer         sql       113130
# 830      Data Engineer      python       108022
# 625       Data Analyst         sql        92428
# 1101    Data Scientist         sql        78982
# ...                ...         ...          ...
# 462       Data Analyst     chainer            1
# 432     Cloud Engineer       wrike            1
# 410     Cloud Engineer      theano            1
# 24    Business Analyst     chainer            1
# 29    Business Analyst  codecommit            1
#
# [2256 rows x 3 columns]

# %%
job_title = 'Data Analyst'
top_skills = 10

df_skill_final = df_skills_count[df_skills_count['job_title_short'] == job_title].head(top_skills)

df_skill_final
# Out:
#     job_title_short  job_skills  skill_count
# 625    Data Analyst         sql        92428
# 494    Data Analyst       excel        66860
# 590    Data Analyst      python        57190
# 638    Data Analyst     tableau        46455
# 583    Data Analyst    power bi        39380
# 594    Data Analyst           r        29996
# 606    Data Analyst         sas        27998
# 585    Data Analyst  powerpoint        13822
# 664    Data Analyst        word        13562
# 605    Data Analyst         sap        11280

# %%
df_skill_final.plot(kind='barh', x='job_skills', y='skill_count')
# Out:
# <Axes: ylabel='job_skills'>

# %%
# we need to invert the axis so that we are showing descending values

# method 1:
# df_skill_final.sort_values('skill_count').plot(kind='barh', x='job_skills', y='skill_count')


# method 2:
df_skill_final.plot(kind='barh', x='job_skills', y='skill_count')
plt.gca().invert_yaxis()

# %%
job_title = 'Data Engineer'
top_skills = 15


df_skill_final = df_skills_count[df_skills_count['job_title_short'] == job_title].head(top_skills)

df_skill_final.plot(kind='barh', x='job_skills', y='skill_count')
plt.gca().invert_yaxis()
plt.title(f'Top {top_skills} skills for {job_title}s')
plt.xlabel('Job Posting Count')
plt.ylabel('')
plt.legend().set_visible(False)
plt.show()
