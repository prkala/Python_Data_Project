# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
# only get data analyst jobs in the US
df_DA_US = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()

# Drop NaN values from the column for plotting
df_DA_US = df_DA_US.dropna(subset=['salary_year_avg'])

# %%
df_DA_US.sample(5)
# Out:
#        job_title_short                                       job_title  \
# 585678    Data Analyst  Data Analyst for the Regional Perinatal Center
# 399113    Data Analyst                                  Data Analyst 2
# 180648    Data Analyst                                    Data Analyst
# 727743    Data Analyst                                    Data Analyst
# 766600    Data Analyst                                    DATA ANALYST
#
#         job_location                 job_via job_schedule_type  \
# 585678  Valhalla, NY              via Indeed         Full-time
# 399113  San Jose, CA  via PayPal - Talentify         Full-time
# 180648    Boston, MA            via LinkedIn         Full-time
# 727743      Anywhere              via Indeed         Full-time
# 766600  New York, NY              via Indeed         Full-time
#
#         job_work_from_home            search_location     job_posted_date  \
# 585678               False    New York, United States 2023-09-20 09:00:00
# ...

# %%
df_DA_US = df_DA_US.explode('job_skills')

df_DA_US['job_skills']
# Out:
# 109        python
# 109             r
# 109       alteryx
# 109       tableau
# 180         excel
#            ...
# 784882        sql
# 784882        vba
# 784882    tableau
# 784882      excel
# 784882    alteryx
# Name: job_skills, Length: 17440, dtype: object

# %%
df_DA_US_group = df_DA_US.groupby('job_skills')['salary_year_avg'].agg(['count','median'])
df_DA_US_group
# Out:
#             count     median
# job_skills
# airflow        44  116250.00
# airtable        5   90000.00
# alteryx       106  106281.25
# angular         8  107500.00
# ansible         1  159640.00
# ...           ...        ...
# wire            4   74250.00
# word          461   81194.75
# workfront       3   75000.00
# wrike           1   75000.00
# zoom           15   80740.00
#
# [170 rows x 2 columns]

# %%
df_DA_top_pay = df_DA_US_group.sort_values('median', ascending = False).head(10)
df_DA_top_pay
# Out:
#               count    median
# job_skills
# dplyr             2  196250.0
# bitbucket         3  189000.0
# gitlab            3  186000.0
# solidity          1  179000.0
# hugging face      1  175000.0
# couchbase         1  160515.0
# ansible           1  159640.0
# mxnet             2  149000.0
# cassandra         6  148250.0
# vmware            1  147500.0

# %%
df_DA_skills = df_DA_US_group.sort_values('count', ascending = False).head(10).sort_values('median', ascending = False)
df_DA_skills
# Out:
#             count    median
# job_skills
# python       1431  97500.00
# tableau      1364  92875.00
# r             893  92500.00
# sql server    286  92500.00
# sql          2508  91000.00
# sas           926  90000.00
# power bi      838  90000.00
# powerpoint    462  85000.00
# excel        1808  84392.00
# word          461  81194.75

# %%
fig, ax = plt.subplots(2,1)

df_DA_top_pay[::-1].plot(kind='barh', y='median', ax=ax[0], legend = False)   # df_DA_top_pay[::-1] reverses the whole dataframe
# alt way of inverting axis: ax[0].invert_yaxis()
ax[0].set_title('Top 10 Highest Paid Skills for Data Analysts')
ax[0].set_ylabel('')
ax[0].set_xlabel('')
ax[0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x,pos: f'${int(x/1000)}K'))

df_DA_skills[::-1].plot(kind='barh', y='median', ax=ax[1], legend = False)
ax[1].set_xlim(ax[0].get_xlim())
ax[1].set_title('Top 10 Most In-Demand Skills for Data Analysts')
ax[1].set_ylabel('')
ax[1].set_xlabel('Median Salary ($USD)')
ax[1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x,pos: f'${int(x/1000)}K'))

fig.tight_layout()

# %%
df_pk = df_DA_US.copy()

# %%
df_pk = df_pk.explode('job_skills')

# %%
df_pk
# Out:
#        job_title_short                              job_title   job_location  \
# 109       Data Analyst  Senior Supply Chain Analytics Analyst       Anywhere
# 109       Data Analyst  Senior Supply Chain Analytics Analyst       Anywhere
# 109       Data Analyst  Senior Supply Chain Analytics Analyst       Anywhere
# 109       Data Analyst  Senior Supply Chain Analytics Analyst       Anywhere
# 180       Data Analyst                       Data Analyst III  Dos Palos, CA
# ...                ...                                    ...            ...
# 784882    Data Analyst   Merchandising Analyst (Data Analyst)     Denton, TX
# 784882    Data Analyst   Merchandising Analyst (Data Analyst)     Denton, TX
# 784882    Data Analyst   Merchandising Analyst (Data Analyst)     Denton, TX
# 784882    Data Analyst   Merchandising Analyst (Data Analyst)     Denton, TX
# 784882    Data Analyst   Merchandising Analyst (Data Analyst)     Denton, TX
#
# ...

# %%
df_pk_1 = df_pk.groupby('job_skills').agg(median_salary = ('salary_year_avg','median'), count = ('job_skills', 'size'))
df_pk_1
# Out:
#             median_salary  count
# job_skills
# airflow         116250.00     44
# airtable         90000.00      5
# alteryx         106281.25    106
# angular         107500.00      8
# ansible         159640.00      1
# ...                   ...    ...
# wire             74250.00      4
# word             81194.75    461
# workfront        75000.00      3
# wrike            75000.00      1
# zoom             80740.00     15
#
# [170 rows x 2 columns]

# %%
df_pk_1.reset_index().sort_values('median_salary', ascending = False).head(10).sort_values('median_salary').plot(kind='barh', x='job_skills', figsize=(6,4))
plt.tight_layout()

# %%
plt.barh()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 plt.barh(df_pk_1, 1)
#
# File d:\anaconda3\envs\python_course\Lib\site-packages\matplotlib\pyplot.py:3010, in barh(y, width, height, left, align, data, **kwargs)
#    2999 @_copy_docstring_and_deprecators(Axes.barh)
#    3000 def barh(
#    3001     y: float | ArrayLike,
#    (...)   3008     **kwargs,
#    3009 ) -> BarContainer:
# -> 3010     return gca().barh(
#    3011         y,
#    3012         width,
#    3013         height=height,
#    3014         left=left,
#    3015         align=align,
#    3016         **({"data": data} if data is not None else {}),
#    3017         **kwargs,
#    3018     )
#
# File d:\anaconda3\envs\python_course\Lib\site-packages\matplotlib\axes\_axes.py:2812, in Axes.barh(self, y, width, height, left, align, data, **kwargs)
#    2693 r"""
# ...
