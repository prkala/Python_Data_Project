# %%
if True:
  print("What's up data nerds")
# Out:
# What's up data nerds

# %%
if False:
  print("Hello")

# %%
job_skill = 'SQL'
applicant_skill = 'SQL'


if job_skill == applicant_skill:
  print("Perfect Match")
# Out:
# Perfect Match

# %%
job_skill = 'SQL'
applicant_skill = 'Python'
years_exp = 3

if job_skill == applicant_skill:
  print("Perfect Match")
elif years_exp >=5:
  print("enough experience; No SQL")
elif(applicant_skill == "Python"):
  print("This applicant should know SQL")
else:
  print("No match")
# Out:
# This applicant should know SQL

# %%
# use of pass: when we don't know what to input for the time being

if job_skill == applicant_skill:
  pass

# %%
# another way
if job_skill == applicant_skill:
  ...
