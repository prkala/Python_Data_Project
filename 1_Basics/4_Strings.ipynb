# %%
"this is a string in single quotes"
# Out:
# 'this is a string in single quotes'

# %%
"this is a string in double quotes"
# Out:
# 'this is a string in double quotes'

# %%
skill = "Python"

# %%
type(skill)
# Out:
# str

# %%
skill.upper()
# Out:
# 'PYTHON'

# %%
skill.lower()
# Out:
# 'python'

# %%
"Python".lower()
# Out:
# 'python'

# %%
str.lower("Python")  # lower is a method of the str class and "Python is and instance of str class"
# Out:
# 'python'

# %%
skill.lower()
# Out:
# 'python'

# %%
skill.replace("P", "J")
# Out:
# 'Jython'

# %%
job_title = 'Data Analyst'  # rename data as doto

# %%
job_title = job_title.replace("a", "o", 2)

# %%
job_title.split(sep = " ", maxsplit = 1 )
# Out:
# ['Doto', 'Analyst']

# %%
str.__add__("Data"," Analyst")   # dunder methods or magic methods
# Out:
# 'Data Analyst'

# %%
"Data".__add__(" Analyst")
# Out:
# 'Data Analyst'

# %%
"Data" + " Analyst"  # + uses the dunder method only
# Out:
# 'Data Analyst'

# %%
"Data Analyst " * 10
# Out:
# 'Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst '

# %%
"Data analysts".__len__()
# Out:
# 13

# %%
len("Data Analysts")
# Out:
# 13

# %%
def abc(a, b):
  return a+b

# %%
abc(4,5)
# Out:
# 9
