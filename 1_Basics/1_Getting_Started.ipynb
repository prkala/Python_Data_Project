# %% [markdown]
# ### **Python Basics**

# %%
print(2+2)
8*9
# Out:
# 4
# 72

# %%
# This is a comment

# %% [markdown]
# # This is a heading
# **bold text**
#
# [link here](www.google.com)

# %%
# magic commands
# time the execution of a code snippet

# %timeit [i**2 for i in range(1000)]
# Out:
# 65.5 µs ± 946 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# for timing multiple lines of code
# %%timeit
L = []
for i in range(1000):
  L.append(i**2)
# Out:
# 74.4 µs ± 5.27 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
