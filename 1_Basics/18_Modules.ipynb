# %%
import my_module

# %%
my_module.skill_list
# Out:
# ['Python', 'SQL', 'Excel']

# %%
my_module.skill("Tableau")
# Out:
# 'Tableau is my favourite skill!'

# %%
import job_analyzer

# %%
job_analyzer.calculate_salary(100000)
# Out:
# 110000.00000000001

# %%
from job_analyzer import calculate_salary

# %%
calculate_salary(100)
# Out:
# 110.00000000000001

# %%
from job_analyzer import calculate_bonus

# %%
calculate_bonus(110,100)
# Out:
# 0.1

# %%
# import all functions from job_analyzer

from job_analyzer import *

# %%
help(calculate_salary)
# Out:
# Help on function calculate_salary in module job_analyzer:
#
# calculate_salary(base_salary, bonus_rate=0.1)
#     calculate the total sal based on the base sal and bonus rate

# %% [markdown]
# ## Python Standard Library

# %%
salary_list = [98000, 101000, 102000, 99000, 97000]

# %%
import statistics

# %%
statistics.mean(salary_list)
# Out:
# 99400

# %%
from statistics import mean, mode, median

# %%
mean(salary_list)
# Out:
# 99400

# %%
mode(salary_list)
# Out:
# 98000

# %%
median(salary_list)
# Out:
# 99000
